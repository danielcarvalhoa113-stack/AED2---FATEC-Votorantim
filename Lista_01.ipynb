# %% [markdown]
# <a href="https://colab.research.google.com/github/danielcarvalhoa113-stack/AED2---FATEC-Votorantim/blob/main/Lista_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Esta é a primeira lista de exercícios do prof. Piva para o segundo semestre, começando por "aquecimentos" para relembrar certas coisas. Vou estar usando um pouco de IA só para identificar o que ha de errado em alguns de meus códigos, além do material de apoio do professor

# %%
# Exercício 1
Frutas = ['Maçã', 'Banana', 'Laranja']

# %%
Frutas.append('Morango')
print(Frutas)
# Out:
# ['Maçã', 'Banana', 'Laranja', 'Morango']

# %%
# Exercício 2, lista criada
livros = []

# %%
# Adicionando elementos a lista
livros.append(input())
print(livros)
# Out:
# 1984
# ['O pequeno príncipe', 'Dom quixote', '1984']

# %%
# Uma vez que a lista está funcionando, agora vamos remover os últimos itens adicionados e exibir a lista restante
print(livros[-1])
livros.pop()
print(livros)
# Out:
# 1984
# ['O pequeno príncipe', 'Dom quixote']

# %%
# Exercício 3, Criar uma lista com os nomes "ana, Bruno, Carla" nessa ordem,
# depois será adicionado um "Daniel" e o primeiro da fila tera de sair.
# Primeiro criamos a lista
clientes = ["Ana","Bruno","Carla"]

# %%
# Exercício 3, Criar uma lista com os nomes "ana, Bruno, Carla" nessa ordem,
# depois será adicionado um "Daniel" e o primeiro da fila tera de sair.
# Primeiro criamos a lista
clientes = ["Ana","Bruno","Carla"]

# Agora é preciso adicionar o novo cliente, e depois remover o que estava em primeiro na lista
clientes.append(input())
print(clientes[0])
clientes.pop(0)
print(clientes)
# Out:
# Daniel
# Ana
# ['Bruno', 'Carla', 'Daniel']

# %%
# Exercício 4, criar um dicionário que tenha o nome e o número do cliente,
# Após isso, irei inserir um novo cliente e vou puxar o número do primeiro cliente na lista
# Talvez esse seja mais díficil, posto que eu não me envolvi muito com dicionários ainda
clientes = {"Ana":"1234-5678","Bruno":"9876-5432"}

# %%
# Agora é hora de adicionar um cliente e chamar o primeiro número
clientes["Carlos"] = "1122-3344"
print(clientes["Ana"])
# Out:
# 1234-5678

# %% [markdown]
# Bom, agora que relebramos algumas coisas, hora que fazer o que aparentemente será o mais difícil. O professor deixou para o  final de cada lista 2 projetos, para testar se aprendeu alguma coisa mesmo

# %%
# Projeto 1, devo criar uma sistema que guarde 2 contatos de uma pessoa,
# de modo que eu possa adicionar contatos e encontrá-los depois de maneira prática
# para isso vou utilizar a estrutura de dicionário pois ela permite o link de "Nome = [Telefone e e-mail]"
contatos = {"Pedro": ["1234-5678","pedr02@gmail.com"], "Ana": ["9876-5432","an4aloprada@gmail.com"]}

# %%
# Esta parte de adicionar um novo contato foi a que mais me deu trabalho e eu recorri ao auxilio da IA para achar o caminho,
# mas não estava muito longe o meu racíocionio.
nome = input()
numero = input()
email = input()
contatos[nome] = [numero, email]
print(contatos)
# Out:
# Daniel
# 1213-0009
# pastelfritadinh0@gmail.com
# {'Pedro': ['1234-5678', 'pedr02@gmail.com'], 'Ana': ['9876-5432', 'an4aloprada@gmail.com'], 'Daniel': ['1213-0009', 'pastelfritadinh0@gmail.com']}

# %%
# Projeto 2, uma lista de tarefas a qual eu posso adicionar tarefas e excluir-las quando concluídas
# A melhor forma de fazer isso, é com uma lista
tarefas = []

# %%
# Agora criamos uma celúla para incluir tarefas
tarefas.append(input())
print(tarefas)
# Out:
# Lavar louça do café da manhã
# ['Arrumar a cama', 'Colocar as roupas para lavar', 'Lavar louça do café da manhã']

# %%
# E uma célula para excluir tarefas
tarefas.remove(input())
print(tarefas)
# Out:
# Lavar louça do café da manhã
# ['Arrumar a cama', 'Colocar as roupas para lavar']
